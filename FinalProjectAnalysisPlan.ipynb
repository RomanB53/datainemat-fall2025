# %%
import json
import pandas as pd
import os 
from datetime import datetime

# %%
with open("/Users/romanbryenton/Desktop/Spotify Account Data 3/StreamingHistory_music_0.json", "r") as f:
    data = json.load(f)

df = pd.DataFrame(data)

# %%
df['endTime'] = pd.to_datetime(df['endTime'])
df.head()
# Out:
#               endTime             artistName                        trackName  \
# 0 2024-11-14 01:16:00        Briston Maroney   Freakin' Out On the Interstate
# 1 2024-11-14 17:20:00       Miniature Tigers                Like or Like Like
# 2 2024-11-14 17:20:00             Kali Uchis                          Melting
# 3 2024-11-14 17:20:00                   Cuco  Bossa No Sé (feat. Jean Carter)
# 4 2024-11-14 17:20:00  Red Hot Chili Peppers                      Scar Tissue
#
#    msPlayed season
# 0     13421   Fall
# 1      6501   Fall
# 2       626   Fall
# 3       603   Fall
# 4       719   Fall

# %%
def get_season(date):
    month = date.month
    if month in [12, 1, 2]:
        return "Winter"
    elif month in [3, 4, 5]:
        return "Spring"
    elif month in [6, 7, 8]:
        return "Summer"
    else:
        return "Fall"

# %%
df['season'] = df['endTime'].apply(get_season)

# %%
df.head(10)
# Out:
#               endTime             artistName                        trackName  \
# 0 2024-11-14 01:16:00        Briston Maroney   Freakin' Out On the Interstate
# 1 2024-11-14 17:20:00       Miniature Tigers                Like or Like Like
# 2 2024-11-14 17:20:00             Kali Uchis                          Melting
# 3 2024-11-14 17:20:00                   Cuco  Bossa No Sé (feat. Jean Carter)
# 4 2024-11-14 17:20:00  Red Hot Chili Peppers                      Scar Tissue
# 5 2024-11-14 17:20:00            Beach House                       Wildflower
# 6 2024-11-14 17:20:00             The Marías                 I Don't Know You
# 7 2024-11-14 17:20:00      Cage The Elephant              Cigarette Daydreams
# 8 2024-11-14 17:20:00             Mac Miller                        Love Lost
# 9 2024-11-14 17:23:00                 fats'e                  room to breathe
#
#    msPlayed season
# 0     13421   Fall
# 1      6501   Fall
# 2       626   Fall
# 3       603   Fall
# ...

# %% [markdown]
# Here, I loaded my data both by artist name and track name. As you can see, as the winter comes, my listening habits are much much higher when it is winter time.

# %%
unique_artists_by_season = df.groupby('season')['artistName'].nunique()
unique_artists_by_season
# Out:
# season
# Fall      152
# Spring    258
# Winter    620
# Name: artistName, dtype: int64

# %%
unique_tracks_by_season = df.groupby('season')['trackName'].nunique()
unique_tracks_by_season
# Out:
# season
# Fall       312
# Spring     630
# Winter    1532
# Name: trackName, dtype: int64
