# %% [markdown]
# ## How I obtained the data
# I obtained this data by using Spotify's "Download my data" feature, which emailed me a zip file containing all of my listening history and habits. I am looking to see how my music listening habits change during different seasons, do I listen to more music in the winter or fall?

# %%
import json as js 
import pandas as pd
import glob
from pathlib import Path

# %%
path = r"/Users/romanbryenton/Desktop/Spotify Account Data/StreamingHistory_music_0.json"

with open(path) as op:
    data = js.load(op)

# %%
type(data)  # dict
# Out:
# list

# %%
data[0]
# Out:
# {'endTime': '2024-11-14 01:16',
#  'artistName': 'Briston Maroney',
#  'trackName': "Freakin' Out On the Interstate",
#  'msPlayed': 13421}

# %%
df = pd.DataFrame(data)
df.head()
# Out:
#             endTime             artistName                        trackName  \
# 0  2024-11-14 01:16        Briston Maroney   Freakin' Out On the Interstate
# 1  2024-11-14 17:20       Miniature Tigers                Like or Like Like
# 2  2024-11-14 17:20             Kali Uchis                          Melting
# 3  2024-11-14 17:20                   Cuco  Bossa No Sé (feat. Jean Carter)
# 4  2024-11-14 17:20  Red Hot Chili Peppers                      Scar Tissue
#
#    msPlayed
# 0     13421
# 1      6501
# 2       626
# 3       603
# 4       719

# %% [markdown]
# ## Data Structure

# %% [markdown]
# After loading my data, it shows what date and the time the song was played at, the artists name, the song name, and even the milliseconds played.

# %%
df = pd.DataFrame(data)
df.head(10)
# Out:
#             endTime             artistName                        trackName  \
# 0  2024-11-14 01:16        Briston Maroney   Freakin' Out On the Interstate
# 1  2024-11-14 17:20       Miniature Tigers                Like or Like Like
# 2  2024-11-14 17:20             Kali Uchis                          Melting
# 3  2024-11-14 17:20                   Cuco  Bossa No Sé (feat. Jean Carter)
# 4  2024-11-14 17:20  Red Hot Chili Peppers                      Scar Tissue
# 5  2024-11-14 17:20            Beach House                       Wildflower
# 6  2024-11-14 17:20             The Marías                 I Don't Know You
# 7  2024-11-14 17:20      Cage The Elephant              Cigarette Daydreams
# 8  2024-11-14 17:20             Mac Miller                        Love Lost
# 9  2024-11-14 17:23                 fats'e                  room to breathe
#
#    msPlayed
# 0     13421
# 1      6501
# 2       626
# 3       603
# 4       719
# 5       557
# 6       626
# 7       673
# ...
